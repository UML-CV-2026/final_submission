# %% [markdown]
# ### Imports

# %%
from fundus_dataset import AugmentPair, FundusVesselDataset, CenterCropPair
from torch.utils.data import DataLoader
import torch.nn as nn
import torch
import matplotlib.pyplot as plt
from torch.utils.data import Subset
from monai.networks.nets import UNet
from monai.losses import DiceLoss
from safetensors.torch import save_file
from pathlib import Path
from cbDice import SoftcbDiceLoss

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ### Testing the Dataset

# %%
img_dir = "fundus/train/Original/"
mask_dir = "fundus/train/Ground truth"

train_full = FundusVesselDataset(
    img_dir=img_dir,
    mask_dir=mask_dir,
    transform=AugmentPair(crop_size=(512, 512)),
)

val_full = FundusVesselDataset(
    img_dir=img_dir,
    mask_dir=mask_dir,
    transform=CenterCropPair(crop_size=(512, 512)),
)

num_samples = len(train_full)
generator = torch.Generator().manual_seed(42)

# Shuffle the indices
indices = torch.randperm(num_samples, generator=generator).tolist()

train_size = int(0.8 * num_samples)

train_indices = indices[:train_size]
val_indices = indices[train_size:]

train_dataset = Subset(train_full, train_indices)
val_dataset = Subset(val_full, val_indices)

# Dataloaders
train_loader = DataLoader(
    train_dataset,
    batch_size=8,
    shuffle=True,
    num_workers=8,
    pin_memory=torch.cuda.is_available(),
)

val_loader = DataLoader(
    val_dataset,
    batch_size=1,
    shuffle=False,
    num_workers=8,
    pin_memory=torch.cuda.is_available(),
)

print(f"Train size: {len(train_dataset)}")
print(f"Val size: {len(val_dataset)}")

images, masks = next(iter(train_loader))
val_images, val_masks = next(iter(val_loader))

print("Train images:", images.shape, images.dtype, images.min().item(), images.max().item())
print("Train masks: ", masks.shape, masks.dtype, torch.unique(masks))

print("Val images:", val_images.shape, val_images.dtype, val_images.min().item(), val_images.max().item())
print("Val masks: ", val_masks.shape, val_masks.dtype, torch.unique(val_masks))
# Out:
# Number of images: 600
# Number of masks: 600
# First 5 image files:  ['100_A.png', '101_A.png', '102_A.png', '103_A.png', '104_A.png']
# First 5 mask files:  ['100_A.png', '101_A.png', '102_A.png', '103_A.png', '104_A.png']
# Number of images: 600
# Number of masks: 600
# First 5 image files:  ['100_A.png', '101_A.png', '102_A.png', '103_A.png', '104_A.png']
# First 5 mask files:  ['100_A.png', '101_A.png', '102_A.png', '103_A.png', '104_A.png']
# Train size: 480
# Val size: 120
# Train images: torch.Size([8, 3, 512, 512]) torch.float32 0.0 0.8784313797950745
# Train masks:  torch.Size([8, 1, 512, 512]) torch.float32 tensor([0., 1.])
# Val images: torch.Size([1, 3, 512, 512]) torch.float32 0.0 1.0
# Val masks:  torch.Size([1, 1, 512, 512]) torch.float32 tensor([0., 1.])

# %% [markdown]
# ### CLDice + BCE + Dice

# %%
import numpy as np

class DiceBCEclDiceLogitsLoss(nn.Module):
    """
    Combined Dice + BCE + Soft cbDice loss for binary segmentation from logits.
    """

    def __init__(self, iter_=3, w_dice=1.0, w_bce=1.0, w_cldice=1.0, smooth=1.0):
        super().__init__()
        self.dice = DiceLoss(sigmoid=True, smooth_nr=smooth, smooth_dr=smooth)
        self.bce = nn.BCEWithLogitsLoss()
        self.cbdice = SoftcbDiceLoss(iter_=iter_, smooth=smooth)
        self.w_dice = w_dice
        self.w_bce = w_bce
        self.w_cldice = w_cldice

    def forward(self, logits, masks):
        dice_loss = self.dice(logits, masks)
        bce_loss = self.bce(logits, masks)

        pred_2ch_logits = torch.cat([torch.zeros_like(logits), logits], dim=1)
        cbdice_raw = self.cbdice(pred_2ch_logits, masks)
        cldice_loss = 1.0 + cbdice_raw

        return self.w_dice * dice_loss + self.w_bce * bce_loss + self.w_cldice * cldice_loss

def hard_dice_score(logits, masks, threshold=0.5, eps=1e-6):
    probs = torch.sigmoid(logits)
    preds = (probs > threshold).float()

    # flatten each image separately: [B, 1, H, W] -> [B, pixels]
    preds = preds.flatten(start_dim=1)
    masks = masks.flatten(start_dim=1)

    intersection = (preds * masks).sum(dim=1)
    denominator = preds.sum(dim=1) + masks.sum(dim=1)

    dice = (2 * intersection + eps) / (denominator + eps)

    return dice.mean()

# %% [markdown]
# ### U-Net Factory

# %%
def make_unet(channels=(16, 32, 64, 128, 256)):
    model = UNet(
        spatial_dims=2,
        in_channels=3,
        out_channels=1,
        channels=channels,
        strides=(2, 2, 2, 2),
        num_res_units=2,
    )
    return model.to(device)

# %% [markdown]
# ### Training Loop Function

# %%
def validate_full_image(model, loader, loss_fn, threshold=0.5, device=torch.device("cuda")):
    model.eval()
    val_loss = 0.0
    val_dice = 0.0
    val_cldice = 0.0

    with torch.no_grad():
        for images, masks in loader:
            images = images.to(device)
            masks = masks.to(device)

            logits = model(images)
            loss = loss_fn(logits, masks)
            dice = hard_dice_score(logits, masks, threshold=threshold)
            # cldice = hard_cldice_score(logits, masks, threshold=threshold)

            val_loss += loss.item() * images.size(0)
            val_dice += dice.item() * images.size(0)
            # val_cldice += cldice.item() * images.size(0)

    val_loss /= len(loader.dataset)
    val_dice /= len(loader.dataset)
    # val_cldice /= len(loader.dataset)
    return val_loss, val_dice


def train_model(model, train_loader, val_loader, loss_fn, optimizer, epochs, save_path=None, save_name="clDice.safetensors", device=torch.device("cuda")):
    history = []
    best_val_loss = float('inf')
    best_epoch = 0
    
    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        train_loss_steps = []

        for images, masks in train_loader:
            images = images.to(device)
            masks = masks.to(device)

            optimizer.zero_grad()

            logits = model(images)
            loss = loss_fn(logits, masks)

            loss.backward()
            optimizer.step()

            step_loss = loss.item()
            train_loss += step_loss * images.size(0)
            train_loss_steps.append(step_loss)

        train_loss /= len(train_loader.dataset)

        # Default validation protocol: full-image metrics on val_loader.
        val_loss, val_dice = validate_full_image(
            model=model,
            loader=val_loader,
            loss_fn=loss_fn,
            threshold=0.5,
        )

        history.append({
            "epoch": epoch + 1,
            "train_loss": train_loss,
            "train_loss_steps": train_loss_steps,
            "val_loss": val_loss,
            "val_dice": val_dice,
            # "val_cldice": val_cldice,
        })

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_epoch = epoch + 1

            if save_path is not None:
                save_dir = Path(save_path)
                save_dir.mkdir(parents=True, exist_ok=True)
                st_path = save_dir / save_name
                save_file(model.state_dict(), st_path)

        print(
            f"Epoch {epoch + 1:03d}/{epochs} | "
            f"Train loss: {train_loss:.4f} | "
            f"Val loss: {val_loss:.4f} | "
            f"Val Dice: {val_dice:.4f} | "
            # f"Val clDice: {val_cldice:.4f} | "
            f"Best: {best_val_loss:.4f} @ {best_epoch}"
        )

    return history

# %% [markdown]
# ### DANGEROUS (RESET EXPERIMENT)

# %%
model = make_unet(channels=(32, 64, 128, 256, 512))
loss_fn = DiceBCEclDiceLogitsLoss(w_bce=0.4, w_dice=0.4, w_cldice=0.2).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
EPOCHS = 100
SAVE_PATH = "/workspace/models_cbdice/"
SAVE_NAME = "cbDice.safetensors"

# %% [markdown]
# ### START OR CONTINUE EXPERIMENT

# %%
history = train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    loss_fn=loss_fn,
    optimizer=optimizer,
    epochs=EPOCHS,
    save_path=SAVE_PATH,
    save_name=SAVE_NAME,
)
# Out:
# Epoch 001/100 | Train loss: 0.8056 | Val loss: 0.8569 | Val Dice: 0.1040 | Best: 0.8569 @ 1
# Epoch 002/100 | Train loss: 0.8098 | Val loss: 0.8671 | Val Dice: 0.1136 | Best: 0.8569 @ 1
# Epoch 003/100 | Train loss: 0.7795 | Val loss: 0.8388 | Val Dice: 0.2185 | Best: 0.8388 @ 3
# Epoch 004/100 | Train loss: 0.7166 | Val loss: 0.7865 | Val Dice: 0.3862 | Best: 0.7865 @ 4
# Epoch 005/100 | Train loss: 0.6458 | Val loss: 0.7098 | Val Dice: 0.5007 | Best: 0.7098 @ 5
# Epoch 006/100 | Train loss: 0.6236 | Val loss: 0.7117 | Val Dice: 0.4857 | Best: 0.7098 @ 5
# Epoch 007/100 | Train loss: 0.5812 | Val loss: 0.6711 | Val Dice: 0.5136 | Best: 0.6711 @ 7
# Epoch 008/100 | Train loss: 0.5348 | Val loss: 0.6341 | Val Dice: 0.5828 | Best: 0.6341 @ 8
# Epoch 009/100 | Train loss: 0.5143 | Val loss: 0.6601 | Val Dice: 0.4958 | Best: 0.6341 @ 8
# Epoch 010/100 | Train loss: 0.4880 | Val loss: 0.5842 | Val Dice: 0.5823 | Best: 0.5842 @ 10
# Epoch 011/100 | Train loss: 0.4614 | Val loss: 0.5861 | Val Dice: 0.5725 | Best: 0.5842 @ 10
# Epoch 012/100 | Train loss: 0.4215 | Val loss: 0.5242 | Val Dice: 0.6330 | Best: 0.5242 @ 12
# Epoch 013/100 | Train loss: 0.3900 | Val loss: 0.5134 | Val Dice: 0.6317 | Best: 0.5134 @ 13
# Epoch 014/100 | Train loss: 0.3443 | Val loss: 0.4375 | Val Dice: 0.6844 | Best: 0.4375 @ 14
# Epoch 015/100 | Train loss: 0.3154 | Val loss: 0.3991 | Val Dice: 0.7159 | Best: 0.3991 @ 15
# Epoch 016/100 | Train loss: 0.2750 | Val loss: 0.3556 | Val Dice: 0.7170 | Best: 0.3556 @ 16
# Epoch 017/100 | Train loss: 0.2569 | Val loss: 0.3252 | Val Dice: 0.7181 | Best: 0.3252 @ 17
# Epoch 018/100 | Train loss: 0.2321 | Val loss: 0.2877 | Val Dice: 0.7411 | Best: 0.2877 @ 18
# Epoch 019/100 | Train loss: 0.2158 | Val loss: 0.2891 | Val Dice: 0.7231 | Best: 0.2877 @ 18
# Epoch 020/100 | Train loss: 0.2010 | Val loss: 0.2727 | Val Dice: 0.7517 | Best: 0.2727 @ 20
# Epoch 021/100 | Train loss: 0.1994 | Val loss: 0.2589 | Val Dice: 0.7417 | Best: 0.2589 @ 21
# Epoch 022/100 | Train loss: 0.1965 | Val loss: 0.2711 | Val Dice: 0.7144 | Best: 0.2589 @ 21
# Epoch 023/100 | Train loss: 0.1929 | Val loss: 0.2299 | Val Dice: 0.7579 | Best: 0.2299 @ 23
# Epoch 076/100 | Train loss: 0.1421 | Val loss: 0.1648 | Val Dice: 0.8112 | Best: 0.1608 @ 72
# Epoch 077/100 | Train loss: 0.1488 | Val loss: 0.1664 | Val Dice: 0.8118 | Best: 0.1608 @ 72
# Epoch 078/100 | Train loss: 0.1391 | Val loss: 0.1785 | Val Dice: 0.8015 | Best: 0.1608 @ 72
# Epoch 079/100 | Train loss: 0.1485 | Val loss: 0.1657 | Val Dice: 0.8003 | Best: 0.1608 @ 72
# Epoch 080/100 | Train loss: 0.1457 | Val loss: 0.1663 | Val Dice: 0.8118 | Best: 0.1608 @ 72
# Epoch 081/100 | Train loss: 0.1460 | Val loss: 0.1807 | Val Dice: 0.7941 | Best: 0.1608 @ 72
# Epoch 082/100 | Train loss: 0.1483 | Val loss: 0.1609 | Val Dice: 0.8125 | Best: 0.1608 @ 72
# Epoch 083/100 | Train loss: 0.1441 | Val loss: 0.1755 | Val Dice: 0.7934 | Best: 0.1608 @ 72
# Epoch 084/100 | Train loss: 0.1474 | Val loss: 0.1823 | Val Dice: 0.7900 | Best: 0.1608 @ 72
# Epoch 085/100 | Train loss: 0.1415 | Val loss: 0.1784 | Val Dice: 0.7971 | Best: 0.1608 @ 72
# Epoch 086/100 | Train loss: 0.1542 | Val loss: 0.1718 | Val Dice: 0.8034 | Best: 0.1608 @ 72
# Epoch 087/100 | Train loss: 0.1421 | Val loss: 0.1614 | Val Dice: 0.8159 | Best: 0.1608 @ 72
# Epoch 088/100 | Train loss: 0.1443 | Val loss: 0.1783 | Val Dice: 0.7953 | Best: 0.1608 @ 72
# Epoch 089/100 | Train loss: 0.1427 | Val loss: 0.1657 | Val Dice: 0.8088 | Best: 0.1608 @ 72
# Epoch 090/100 | Train loss: 0.1459 | Val loss: 0.1633 | Val Dice: 0.8153 | Best: 0.1608 @ 72
# Epoch 091/100 | Train loss: 0.1383 | Val loss: 0.1849 | Val Dice: 0.7948 | Best: 0.1608 @ 72
# Epoch 092/100 | Train loss: 0.1442 | Val loss: 0.1802 | Val Dice: 0.7801 | Best: 0.1608 @ 72
# Epoch 093/100 | Train loss: 0.1415 | Val loss: 0.1692 | Val Dice: 0.8014 | Best: 0.1608 @ 72
# Epoch 094/100 | Train loss: 0.1450 | Val loss: 0.1685 | Val Dice: 0.8053 | Best: 0.1608 @ 72
# Epoch 095/100 | Train loss: 0.1417 | Val loss: 0.1619 | Val Dice: 0.8198 | Best: 0.1608 @ 72
# Epoch 096/100 | Train loss: 0.1396 | Val loss: 0.1603 | Val Dice: 0.8152 | Best: 0.1603 @ 96
# Epoch 097/100 | Train loss: 0.1429 | Val loss: 0.1573 | Val Dice: 0.8203 | Best: 0.1573 @ 97
# Epoch 098/100 | Train loss: 0.1456 | Val loss: 0.1714 | Val Dice: 0.8046 | Best: 0.1573 @ 97
# Epoch 099/100 | Train loss: 0.1463 | Val loss: 0.1656 | Val Dice: 0.8078 | Best: 0.1573 @ 97
# Epoch 100/100 | Train loss: 0.1420 | Val loss: 0.1648 | Val Dice: 0.8118 | Best: 0.1573 @ 97

# %% [markdown]
# ### Save your Settings

# %%
import pandas as pd

history_df = pd.DataFrame(history)
history_df.to_csv("/workspace/models_cbdice/cbDice_history.csv", index=False)
