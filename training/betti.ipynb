# %% [markdown]
# ### Imports

# %%
from fundus_dataset import AugmentPair, FundusVesselDataset, CenterCropPair
from torch.utils.data import DataLoader
import torch.nn as nn
import torch
from topolosses.losses import BettiMatchingLoss
import matplotlib.pyplot as plt
from torch.utils.data import Subset
from monai.networks.nets import UNet
from monai.losses import DiceLoss, SoftclDiceLoss
from safetensors.torch import save_file
from pathlib import Path

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ### Testing the Dataset

# %%
img_dir = "fundus/train/Original/"
mask_dir = "fundus/train/Ground truth"

train_full = FundusVesselDataset(
    img_dir=img_dir,
    mask_dir=mask_dir,
    transform=AugmentPair(crop_size=(512, 512)),
)

val_full = FundusVesselDataset(
    img_dir=img_dir,
    mask_dir=mask_dir,
    transform=CenterCropPair(crop_size=(512, 512)),
)

num_samples = len(train_full)
generator = torch.Generator().manual_seed(42)

# Shuffle the indices
indices = torch.randperm(num_samples, generator=generator).tolist()

train_size = int(0.8 * num_samples)

train_indices = indices[:train_size]
val_indices = indices[train_size:]

train_dataset = Subset(train_full, train_indices)
val_dataset = Subset(val_full, val_indices)

# Dataloaders
train_loader = DataLoader(
    train_dataset,
    batch_size=8,
    shuffle=True,
    num_workers=8,
    pin_memory=torch.cuda.is_available(),
)

val_loader = DataLoader(
    val_dataset,
    batch_size=1,
    shuffle=False,
    num_workers=8,
    pin_memory=torch.cuda.is_available(),
)

print(f"Train size: {len(train_dataset)}")
print(f"Val size: {len(val_dataset)}")

images, masks = next(iter(train_loader))
val_images, val_masks = next(iter(val_loader))

print("Train images:", images.shape, images.dtype, images.min().item(), images.max().item())
print("Train masks: ", masks.shape, masks.dtype, torch.unique(masks))

print("Val images:", val_images.shape, val_images.dtype, val_images.min().item(), val_images.max().item())
print("Val masks: ", val_masks.shape, val_masks.dtype, torch.unique(val_masks))
# Out:
# Number of images: 600
# Number of masks: 600
# First 5 image files:  ['100_A.png', '101_A.png', '102_A.png', '103_A.png', '104_A.png']
# First 5 mask files:  ['100_A.png', '101_A.png', '102_A.png', '103_A.png', '104_A.png']
# Number of images: 600
# Number of masks: 600
# First 5 image files:  ['100_A.png', '101_A.png', '102_A.png', '103_A.png', '104_A.png']
# First 5 mask files:  ['100_A.png', '101_A.png', '102_A.png', '103_A.png', '104_A.png']
# Train size: 480
# Val size: 120
# Train images: torch.Size([8, 3, 512, 512]) torch.float32 0.0 0.9450980424880981
# Train masks:  torch.Size([8, 1, 512, 512]) torch.float32 tensor([0., 1.])
# Val images: torch.Size([1, 3, 512, 512]) torch.float32 0.0 1.0
# Val masks:  torch.Size([1, 1, 512, 512]) torch.float32 tensor([0., 1.])

# %% [markdown]
# ### CLDice + BCE + Dice

# %%
import numpy as np

class BCEBettiDiceLoss(nn.Module):
    def __init__(self, w_bce=0.5, w_dice=0.5, w_betti=0.001):
        super().__init__()
        self.w_bce = w_bce
        self.w_dice = w_dice
        self.w_betti = w_betti
        self.bce = nn.BCEWithLogitsLoss()
        self.dice = DiceLoss(sigmoid=True)
        self.betti = BettiMatchingLoss(
            alpha=1.0,
            filtration_type="bothlevels",
            num_processes=4,
            push_unmatched_to_1_0=True,
            barcode_length_threshold=0.0,
            topology_weights=(1.0, 1.0),
            sphere=False,
            sigmoid=True,
        )

    def forward(self, logits, masks):
        bce_loss = self.bce(logits, masks)
        dice_loss = self.dice(logits, masks)
        betti_loss = self.betti(logits, masks)

        total = (
            self.w_bce * bce_loss
            + self.w_dice * dice_loss
            + self.w_betti * betti_loss
        )

        return total
        
def hard_dice_score(logits, masks, threshold=0.5, eps=1e-6):
    probs = torch.sigmoid(logits)
    preds = (probs > threshold).float()

    # flatten each image separately: [B, 1, H, W] -> [B, pixels]
    preds = preds.flatten(start_dim=1)
    masks = masks.flatten(start_dim=1)

    intersection = (preds * masks).sum(dim=1)
    denominator = preds.sum(dim=1) + masks.sum(dim=1)

    dice = (2 * intersection + eps) / (denominator + eps)

    return dice.mean()

def hard_cldice_score(logits, masks, threshold=0.5, eps=1e-6):
    del eps  # kept for API parity with hard_dice_score
    from cldice import clDice

    probs = torch.sigmoid(logits)
    preds = (probs > threshold)
    masks = (masks > 0.5)

    # [B, 1, H, W] -> [B, H, W]
    preds = preds.squeeze(1)
    masks = masks.squeeze(1)

    cldice_scores = []
    for pred_i, mask_i in zip(preds, masks):
        pred_np = pred_i.detach().cpu().numpy().astype(np.bool_)
        mask_np = mask_i.detach().cpu().numpy().astype(np.bool_)

        if not pred_np.any() and not mask_np.any():
            score = 1.0
        else:
            score = float(clDice(pred_np, mask_np))
            if not np.isfinite(score):
                score = 0.0

        cldice_scores.append(score)

    if len(cldice_scores) == 0:
        return torch.tensor(0.0, device=logits.device)

    return torch.tensor(sum(cldice_scores) / len(cldice_scores), device=logits.device)

# %% [markdown]
# ### U-Net Factory

# %%
def make_unet(channels=(16, 32, 64, 128, 256)):
    model = UNet(
        spatial_dims=2,
        in_channels=3,
        out_channels=1,
        channels=channels,
        strides=(2, 2, 2, 2),
        num_res_units=2,
    )
    return model.to(device)

# %% [markdown]
# ### Training Loop Function

# %%
def validate_full_image(model, loader, loss_fn, threshold=0.5):
    model.eval()
    val_loss = 0.0
    val_dice = 0.0

    with torch.no_grad():
        for images, masks in loader:
            images = images.to(device)
            masks = masks.to(device)

            logits = model(images)
            loss = loss_fn(logits, masks)
            dice = hard_dice_score(logits, masks, threshold=threshold)

            val_loss += loss.item() * images.size(0)
            val_dice += dice.item() * images.size(0)

    val_loss /= len(loader.dataset)
    val_dice /= len(loader.dataset)
    return val_loss, val_dice


def train_model(model, train_loader, val_loader, loss_fn, optimizer, epochs, save_path=None, save_name="baseline.safetensors"):
    history = []
    best_val_dice = 0.0
    best_epoch = 0
    
    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        train_loss_steps = []

        for images, masks in train_loader:
            images = images.to(device)
            masks = masks.to(device)

            optimizer.zero_grad()

            logits = model(images)
            loss = loss_fn(logits, masks)

            loss.backward()
            optimizer.step()

            step_loss = loss.item()
            train_loss += step_loss * images.size(0)
            train_loss_steps.append(step_loss)

        train_loss /= len(train_loader.dataset)

        # Default validation protocol: full-image metrics on val_loader.
        val_loss, val_dice = validate_full_image(
            model=model,
            loader=val_loader,
            loss_fn=loss_fn,
            threshold=0.5,
        )

        history.append({
            "epoch": epoch + 1,
            "train_loss": train_loss,
            "train_loss_steps": train_loss_steps,
            "val_loss": val_loss,
            "val_dice": val_dice,
        })

        if val_dice > best_val_dice:
            best_val_dice = val_dice
            best_epoch = epoch + 1

            if save_path is not None:
                save_dir = Path(save_path)
                save_dir.mkdir(parents=True, exist_ok=True)
                st_path = save_dir / save_name
                save_file(model.state_dict(), st_path)

        print(
            f"Epoch {epoch + 1:03d}/{epochs} | "
            f"Train loss: {train_loss:.4f} | "
            f"Val loss: {val_loss:.4f} | "
            f"Val Dice: {val_dice:.4f} | "
            f"Best: {best_val_dice:.4f} @ {best_epoch}"
        )

    return history

# %% [markdown]
# ### DANGEROUS (RESET EXPERIMENT)

# %%
model = make_unet(channels=(32, 64, 128, 256, 512))
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn = BCEBettiDiceLoss(
    w_bce=0.5,
    w_dice=0.5,
    w_betti=1e-5,
)
EPOCHS = 100
SAVE_PATH = "/workspace/models_betti/"
SAVE_NAME = "betti.safetensors"

# %% [markdown]
# ### START OR CONTINUE EXPERIMENT

# %%
history = train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    loss_fn=loss_fn,
    optimizer=optimizer,
    epochs=EPOCHS,
    save_path=SAVE_PATH,
    save_name=SAVE_NAME,
)
# Out:
# /root/Computer-Vision-2026/.venv/lib/python3.12/site-packages/topolosses/losses/betti_matching/src/betti_matching_loss.py:155: UserWarning: Single-channel prediction detected. The `include_background=False` setting  will be ignored.
#   warnings.warn(
# Epoch 001/100 | Train loss: 1.3690 | Val loss: 1.2678 | Val Dice: 0.2105 | Best: 0.2105 @ 1
# Epoch 002/100 | Train loss: 1.1354 | Val loss: 1.0608 | Val Dice: 0.3009 | Best: 0.3009 @ 2
# Epoch 003/100 | Train loss: 1.0062 | Val loss: 1.0134 | Val Dice: 0.3798 | Best: 0.3798 @ 3
# Epoch 004/100 | Train loss: 0.9250 | Val loss: 0.9883 | Val Dice: 0.4099 | Best: 0.4099 @ 4
# Epoch 005/100 | Train loss: 0.8852 | Val loss: 0.9385 | Val Dice: 0.3959 | Best: 0.4099 @ 4
# Epoch 006/100 | Train loss: 0.8035 | Val loss: 0.8516 | Val Dice: 0.4856 | Best: 0.4856 @ 6
# Epoch 007/100 | Train loss: 0.7970 | Val loss: 0.8533 | Val Dice: 0.4791 | Best: 0.4856 @ 6
# Epoch 008/100 | Train loss: 0.7645 | Val loss: 0.8235 | Val Dice: 0.5575 | Best: 0.5575 @ 8
# Epoch 009/100 | Train loss: 0.7213 | Val loss: 0.7651 | Val Dice: 0.5906 | Best: 0.5906 @ 9
# Epoch 010/100 | Train loss: 0.7079 | Val loss: 0.7698 | Val Dice: 0.6009 | Best: 0.6009 @ 10
# Epoch 011/100 | Train loss: 0.6768 | Val loss: 0.8258 | Val Dice: 0.5716 | Best: 0.6009 @ 10
# Epoch 012/100 | Train loss: 0.7061 | Val loss: 0.8246 | Val Dice: 0.6206 | Best: 0.6206 @ 12
# Epoch 013/100 | Train loss: 0.7316 | Val loss: 0.8081 | Val Dice: 0.6398 | Best: 0.6398 @ 13
# Epoch 014/100 | Train loss: 0.7368 | Val loss: 0.8577 | Val Dice: 0.6832 | Best: 0.6832 @ 14
# Epoch 015/100 | Train loss: 0.8029 | Val loss: 0.8810 | Val Dice: 0.7354 | Best: 0.7354 @ 15
# Epoch 016/100 | Train loss: 0.7946 | Val loss: 0.8880 | Val Dice: 0.7321 | Best: 0.7354 @ 15
# Epoch 017/100 | Train loss: 0.7900 | Val loss: 0.8338 | Val Dice: 0.5715 | Best: 0.7354 @ 15
# Epoch 018/100 | Train loss: 0.8010 | Val loss: 0.8437 | Val Dice: 0.6854 | Best: 0.7354 @ 15
# Epoch 019/100 | Train loss: 0.8049 | Val loss: 0.9124 | Val Dice: 0.7480 | Best: 0.7480 @ 19
# Epoch 020/100 | Train loss: 0.8090 | Val loss: 0.9778 | Val Dice: 0.7473 | Best: 0.7480 @ 19
# Epoch 021/100 | Train loss: 0.8123 | Val loss: 0.8435 | Val Dice: 0.7322 | Best: 0.7480 @ 19
# Epoch 022/100 | Train loss: 0.8042 | Val loss: 0.8033 | Val Dice: 0.7250 | Best: 0.7480 @ 19
# Epoch 023/100 | Train loss: 0.7965 | Val loss: 0.8119 | Val Dice: 0.7403 | Best: 0.7480 @ 19
# Epoch 024/100 | Train loss: 0.7584 | Val loss: 0.7861 | Val Dice: 0.7589 | Best: 0.7589 @ 24
# Epoch 025/100 | Train loss: 0.7896 | Val loss: 0.9063 | Val Dice: 0.7404 | Best: 0.7589 @ 24
# Epoch 026/100 | Train loss: 0.7691 | Val loss: 0.8603 | Val Dice: 0.7393 | Best: 0.7589 @ 24
# Epoch 027/100 | Train loss: 0.7855 | Val loss: 0.9201 | Val Dice: 0.7805 | Best: 0.7805 @ 27
# Epoch 028/100 | Train loss: 0.7936 | Val loss: 0.8101 | Val Dice: 0.7691 | Best: 0.7805 @ 27
# Epoch 029/100 | Train loss: 0.8088 | Val loss: 0.8260 | Val Dice: 0.7616 | Best: 0.7805 @ 27
# Epoch 030/100 | Train loss: 0.7490 | Val loss: 0.8183 | Val Dice: 0.7853 | Best: 0.7853 @ 30
# Epoch 031/100 | Train loss: 0.7640 | Val loss: 0.8646 | Val Dice: 0.7870 | Best: 0.7870 @ 31
# Epoch 032/100 | Train loss: 0.7935 | Val loss: 0.8443 | Val Dice: 0.7537 | Best: 0.7870 @ 31
# Epoch 033/100 | Train loss: 0.7595 | Val loss: 0.8174 | Val Dice: 0.7920 | Best: 0.7920 @ 33
# Epoch 034/100 | Train loss: 0.7464 | Val loss: 0.9345 | Val Dice: 0.7838 | Best: 0.7920 @ 33
# Epoch 035/100 | Train loss: 0.7779 | Val loss: 0.8386 | Val Dice: 0.7853 | Best: 0.7920 @ 33
# Epoch 036/100 | Train loss: 0.7794 | Val loss: 0.8991 | Val Dice: 0.7837 | Best: 0.7920 @ 33
# Epoch 037/100 | Train loss: 0.7208 | Val loss: 0.7688 | Val Dice: 0.7826 | Best: 0.7920 @ 33
# Epoch 038/100 | Train loss: 0.7345 | Val loss: 0.8391 | Val Dice: 0.7739 | Best: 0.7920 @ 33
# Epoch 039/100 | Train loss: 0.7480 | Val loss: 0.9871 | Val Dice: 0.7838 | Best: 0.7920 @ 33
# Epoch 040/100 | Train loss: 0.7455 | Val loss: 0.7868 | Val Dice: 0.7895 | Best: 0.7920 @ 33
# Epoch 041/100 | Train loss: 0.7233 | Val loss: 0.7966 | Val Dice: 0.7762 | Best: 0.7920 @ 33
# Epoch 042/100 | Train loss: 0.7195 | Val loss: 0.8226 | Val Dice: 0.7953 | Best: 0.7953 @ 42
# Epoch 043/100 | Train loss: 0.7230 | Val loss: 0.9065 | Val Dice: 0.7607 | Best: 0.7953 @ 42
# Epoch 044/100 | Train loss: 0.7248 | Val loss: 0.6836 | Val Dice: 0.7728 | Best: 0.7953 @ 42
# Epoch 045/100 | Train loss: 0.6970 | Val loss: 0.8084 | Val Dice: 0.7905 | Best: 0.7953 @ 42
# Epoch 046/100 | Train loss: 0.7258 | Val loss: 0.7835 | Val Dice: 0.7871 | Best: 0.7953 @ 42
# Epoch 047/100 | Train loss: 0.6979 | Val loss: 0.7464 | Val Dice: 0.8032 | Best: 0.8032 @ 47
# Epoch 048/100 | Train loss: 0.7051 | Val loss: 0.8503 | Val Dice: 0.7889 | Best: 0.8032 @ 47
# Epoch 049/100 | Train loss: 0.7124 | Val loss: 0.7657 | Val Dice: 0.7979 | Best: 0.8032 @ 47
# Epoch 050/100 | Train loss: 0.6835 | Val loss: 0.8237 | Val Dice: 0.8067 | Best: 0.8067 @ 50
# Epoch 051/100 | Train loss: 0.7198 | Val loss: 0.8017 | Val Dice: 0.8067 | Best: 0.8067 @ 50
# Epoch 052/100 | Train loss: 0.6956 | Val loss: 0.8406 | Val Dice: 0.7891 | Best: 0.8067 @ 50
# Epoch 053/100 | Train loss: 0.7002 | Val loss: 0.7651 | Val Dice: 0.8077 | Best: 0.8077 @ 53
# Epoch 054/100 | Train loss: 0.6651 | Val loss: 0.7401 | Val Dice: 0.7844 | Best: 0.8077 @ 53
# Epoch 055/100 | Train loss: 0.6788 | Val loss: 0.7283 | Val Dice: 0.8004 | Best: 0.8077 @ 53
# Epoch 056/100 | Train loss: 0.6626 | Val loss: 0.7208 | Val Dice: 0.7846 | Best: 0.8077 @ 53
# Epoch 057/100 | Train loss: 0.6691 | Val loss: 0.7141 | Val Dice: 0.8074 | Best: 0.8077 @ 53
# Epoch 058/100 | Train loss: 0.6721 | Val loss: 0.7863 | Val Dice: 0.7901 | Best: 0.8077 @ 53
# Epoch 059/100 | Train loss: 0.6462 | Val loss: 0.7573 | Val Dice: 0.8026 | Best: 0.8077 @ 53
# Epoch 060/100 | Train loss: 0.6470 | Val loss: 0.6945 | Val Dice: 0.7997 | Best: 0.8077 @ 53
# Epoch 061/100 | Train loss: 0.6432 | Val loss: 0.7459 | Val Dice: 0.8036 | Best: 0.8077 @ 53
# Epoch 062/100 | Train loss: 0.6346 | Val loss: 0.7587 | Val Dice: 0.8121 | Best: 0.8121 @ 62
# Epoch 063/100 | Train loss: 0.6332 | Val loss: 0.7469 | Val Dice: 0.8013 | Best: 0.8121 @ 62
# Epoch 064/100 | Train loss: 0.6386 | Val loss: 0.7380 | Val Dice: 0.7938 | Best: 0.8121 @ 62
# Epoch 065/100 | Train loss: 0.6343 | Val loss: 0.7518 | Val Dice: 0.7866 | Best: 0.8121 @ 62
# Epoch 066/100 | Train loss: 0.6448 | Val loss: 0.7143 | Val Dice: 0.8034 | Best: 0.8121 @ 62
# Epoch 067/100 | Train loss: 0.6431 | Val loss: 0.7876 | Val Dice: 0.8033 | Best: 0.8121 @ 62
# Epoch 068/100 | Train loss: 0.6688 | Val loss: 0.7350 | Val Dice: 0.8137 | Best: 0.8137 @ 68
# Epoch 069/100 | Train loss: 0.6490 | Val loss: 0.6675 | Val Dice: 0.8001 | Best: 0.8137 @ 68
# Epoch 070/100 | Train loss: 0.6365 | Val loss: 0.7051 | Val Dice: 0.8004 | Best: 0.8137 @ 68
# Epoch 071/100 | Train loss: 0.6228 | Val loss: 0.6947 | Val Dice: 0.8027 | Best: 0.8137 @ 68
# Epoch 072/100 | Train loss: 0.6327 | Val loss: 0.7650 | Val Dice: 0.8033 | Best: 0.8137 @ 68
# Epoch 073/100 | Train loss: 0.6425 | Val loss: 0.7696 | Val Dice: 0.8040 | Best: 0.8137 @ 68
# Epoch 074/100 | Train loss: 0.6646 | Val loss: 0.7323 | Val Dice: 0.7964 | Best: 0.8137 @ 68
# Epoch 075/100 | Train loss: 0.6553 | Val loss: 0.6960 | Val Dice: 0.7971 | Best: 0.8137 @ 68
# Epoch 076/100 | Train loss: 0.6623 | Val loss: 0.7445 | Val Dice: 0.8152 | Best: 0.8152 @ 76
# Epoch 077/100 | Train loss: 0.6445 | Val loss: 0.7078 | Val Dice: 0.8147 | Best: 0.8152 @ 76
# Epoch 078/100 | Train loss: 0.6409 | Val loss: 0.6965 | Val Dice: 0.7782 | Best: 0.8152 @ 76
# Epoch 079/100 | Train loss: 0.6413 | Val loss: 0.7547 | Val Dice: 0.8061 | Best: 0.8152 @ 76
# Epoch 080/100 | Train loss: 0.6481 | Val loss: 0.7028 | Val Dice: 0.8075 | Best: 0.8152 @ 76
# Epoch 081/100 | Train loss: 0.6454 | Val loss: 0.6928 | Val Dice: 0.8056 | Best: 0.8152 @ 76
# Epoch 082/100 | Train loss: 0.6534 | Val loss: 0.7620 | Val Dice: 0.8156 | Best: 0.8156 @ 82
# Epoch 083/100 | Train loss: 0.6637 | Val loss: 0.7880 | Val Dice: 0.8203 | Best: 0.8203 @ 83
# Epoch 084/100 | Train loss: 0.6379 | Val loss: 0.6501 | Val Dice: 0.8146 | Best: 0.8203 @ 83
# Epoch 085/100 | Train loss: 0.6457 | Val loss: 0.6894 | Val Dice: 0.7941 | Best: 0.8203 @ 83
# Epoch 086/100 | Train loss: 0.6341 | Val loss: 0.7184 | Val Dice: 0.8161 | Best: 0.8203 @ 83
# Epoch 087/100 | Train loss: 0.6542 | Val loss: 0.6597 | Val Dice: 0.8149 | Best: 0.8203 @ 83
# Epoch 088/100 | Train loss: 0.6439 | Val loss: 0.7456 | Val Dice: 0.8080 | Best: 0.8203 @ 83
# Epoch 089/100 | Train loss: 0.6568 | Val loss: 0.7303 | Val Dice: 0.8102 | Best: 0.8203 @ 83
# Epoch 090/100 | Train loss: 0.6428 | Val loss: 0.6836 | Val Dice: 0.8109 | Best: 0.8203 @ 83
# Epoch 091/100 | Train loss: 0.6527 | Val loss: 0.7049 | Val Dice: 0.8291 | Best: 0.8291 @ 91
# Epoch 092/100 | Train loss: 0.6487 | Val loss: 0.6844 | Val Dice: 0.7987 | Best: 0.8291 @ 91
# Epoch 093/100 | Train loss: 0.6329 | Val loss: 0.6920 | Val Dice: 0.8126 | Best: 0.8291 @ 91
# Epoch 094/100 | Train loss: 0.6208 | Val loss: 0.6859 | Val Dice: 0.8221 | Best: 0.8291 @ 91
# Epoch 095/100 | Train loss: 0.6278 | Val loss: 0.6947 | Val Dice: 0.8146 | Best: 0.8291 @ 91
# Epoch 096/100 | Train loss: 0.6620 | Val loss: 0.7311 | Val Dice: 0.8081 | Best: 0.8291 @ 91
# Epoch 097/100 | Train loss: 0.6312 | Val loss: 0.6802 | Val Dice: 0.8143 | Best: 0.8291 @ 91
# Epoch 098/100 | Train loss: 0.6296 | Val loss: 0.7188 | Val Dice: 0.8169 | Best: 0.8291 @ 91
# Epoch 099/100 | Train loss: 0.6522 | Val loss: 0.7014 | Val Dice: 0.8293 | Best: 0.8293 @ 99
# Epoch 100/100 | Train loss: 0.6471 | Val loss: 0.6903 | Val Dice: 0.8176 | Best: 0.8293 @ 99

# %% [markdown]
# ### Save your Settings

# %%
import pandas as pd

history_df = pd.DataFrame(history)
history_df.to_csv("/workspace/models_betti/betti_history.csv", index=False)

# %% [markdown]
# ### Top 5 Best clDice
#
# Highest hard clDice values on the test set (best per-image topological overlap).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

from skimage.morphology import skeletonize, binary_dilation


# -----------------------
# Find best 5 by hard clDice
# -----------------------

top5_cldice = sorted(rows, key=lambda r: r["hard_cldice"], reverse=True)[:5]

summary = pd.DataFrame(top5_cldice)[
    ["image", "hard_cldice", "dice", "b0_error", "b1_error", "betti_error"]
]

print(summary.to_string(index=False))


# -----------------------
# Helpers
# -----------------------

name_to_idx = {name: idx for idx, name in enumerate(test_ds.images)}


def predict_mask(model, image, threshold=0.5):
    image = image.unsqueeze(0).to(device)

    with torch.no_grad():
        logits = model(image)
        probs = torch.sigmoid(logits)

    return (probs > threshold).cpu().numpy()[0, 0]


def make_skeleton_overlay(pred_mask):
    skeleton = skeletonize(pred_mask > 0)
    return binary_dilation(
        skeleton,
        footprint=np.ones((3, 3), dtype=bool),
    )


def show_cldice_example(row):
    image_name = row["image"]
    idx = name_to_idx[image_name]

    image, mask = test_ds[idx]

    pred_mask = predict_mask(eval_model, image)
    skeleton_overlay = make_skeleton_overlay(pred_mask)

    original = image.numpy().transpose(1, 2, 0)
    gt_mask = mask.numpy()[0]

    fig, axes = plt.subplots(1, 3, figsize=(14, 4))

    axes[0].imshow(np.clip(original, 0.0, 1.0))
    axes[0].set_title("Original")

    axes[1].imshow(gt_mask, cmap="gray", vmin=0, vmax=1)
    axes[1].set_title("Ground truth")

    axes[2].imshow(pred_mask, cmap="gray", vmin=0, vmax=1)
    axes[2].imshow(
        np.ma.masked_where(~skeleton_overlay, skeleton_overlay),
        cmap="autumn",
        alpha=0.95,
    )
    axes[2].set_title("Prediction + skeleton")

    for ax in axes:
        ax.axis("off")

    fig.suptitle(
        f"{image_name} | "
        f"hard_cldice={row['hard_cldice']:.4f} | "
        f"dice={row['dice']:.4f} | "
        f"betti_error={row['betti_error']:.2f}",
        fontsize=11,
    )

    plt.tight_layout()
    plt.show()


# -----------------------
# Plot best examples
# -----------------------

eval_model.eval()

for row in top5_cldice:
    show_cldice_example(row)
# Out:
#     image  hard_cldice     dice  b0_error  b1_error  betti_error
#  13_A.png     0.966293 0.945821        28         4           32
#  48_A.png     0.961927 0.946883        51         6           57
# 131_G.png     0.961724 0.946545        44         4           48
#  14_A.png     0.961625 0.945118        50         7           57
#  32_A.png     0.961206 0.945099        51         9           60
# /tmp/ipykernel_419528/1539098241.py:41: FutureWarning: `binary_dilation` is deprecated since version 0.26 and will be removed in version 0.28. Use `skimage.morphology.dilation` instead. Note the lack of mirroring for non-symmetric footprints (see docstring notes).
#   return binary_dilation(
